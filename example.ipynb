# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")

# %%
from whatsappy.wppy import parse_file, plot_word, plot_count, general_cloud, plot_hours
df = parse_file(text_file='chats/tomas.txt')
# Out:
# 31/12/18 6:45 - Los mensajes y llamadas en este chat ahora están protegidos con cifrado de extremo a extremo. Toca para más información.
#
# local variable 'date' referenced before assignment
# Me acuerdo de haber creado eso
#
# list index out of range
# ?
#
# list index out of range
#
#
# list index out of range
# Hola! En Globalwork estamos buscando DATA ANALYST
#
# list index out of range
#
#
# list index out of range
#
#
# list index out of range
# Opcional conocimientos en bases de datos no relacionales.
#
# list index out of range
# Opcional conocimientos en plataformas de reporting y graficación de datos.
#
# list index out of range
# Inglés nivel medio / alto
#
# list index out of range
# Disponibilidad para residencia en Medellín, Colombia
#
# list index out of range
# Jajajajaja
#
# list index out of range
#
#
# list index out of range
# Cada vez que entras o haces refresh en thispersondoesnotexist.com verás un rostro distinto. La parte _creepy_ es que todos son generados por un algoritmo de machine learning e inteligencia artificial. Sí, todos. *TODOS*.
#
# list index out of range
# ?
#
# list index out of range
#
#
# list index out of range
# However, the word "human" is not of Germanic origin. The Latin word homo means "human", and its adjective form humanus means "of human" or "humane". The word went into Old French and become humain(e), and then went to late Middle English humaine, which eventually turns into the word "human" now. If you know French, you must know the word humain. It has the same origin with "human".
#
# list index out of range
#
#
# list index out of range
# From the etymology we can know that the two words are from Germanic origin and Roman origin respectively. They just own the part of "MAN" coincidentally.
#
# list index out of range
#
#
# list index out of range
# Usually, the Roman origin words form their plurals by adding an "s". So the plural of the word "human" is "humans" instead of "humen".
#
# list index out of range
# Chao
#
# list index out of range
# Ubuntu al del trabajo
#
# list index out of range
# import scipy as cp
#
# list index out of range
# from scipy import stats
#
# list index out of range
# from sklearn.linear_model import LinearRegression
#
# list index out of range
# from sklearn.metrics import mean_squared_error, r2_score
#
# list index out of range
# from os import listdir
#
# list index out of range
# from os.path import isfile, join
#
# list index out of range
# import os
#
# list index out of range
# import time
#
# list index out of range
# import plotly
#
# list index out of range
# import plotly.plotly as py
#
# list index out of range
# import plotly.graph_objs as go
#
# list index out of range
# from plotly.offline import *
#
# list index out of range
#
#
# list index out of range
# ## Funciones
#
# list index out of range
# def find_nearest(array, value):
#
# list index out of range
#     array = np.asarray(array)
#
# list index out of range
#     return idx
#
# list index out of range
#
#
# list index out of range
# def graficar(nombregrafica, fecha,x1,y1,x2,y2,x3,y3,toh):
#
# list index out of range
#     nombre = nombregrafica
#
# list index out of range
#     n = 1
#
# list index out of range
#
#
# list index out of range
#     while os.path.isfile(nombre + "_" + fecha + '.html'):
#
# list index out of range
#         nombre = nombregrafica + '_(' + str(n) + ')'
#
# list index out of range
#         n += 1
#
# list index out of range
#
#
# list index out of range
#     titulo = 'Calibracion ' + nombregrafica
#
# list index out of range
#     n1 = 'Camara'
#
# list index out of range
#     n2 = 'Sensor'
#
# list index out of range
#     n3 = 'Ajuste'
#
# list index out of range
#
#
# list index out of range
#
#
# list index out of range
#     trace1 = go.Scatter(x=x1, y=y1, name=n1, marker=dict(color='blue'))
#
# list index out of range
#     trace2 = go.Scatter(x=x2, y=y2, name=n2, yaxis='y', marker=dict(color='orange'))
#
# list index out of range
#     trace3 = go.Scatter(x=x3, y=y3, name=n3, yaxis='y', marker=dict(color='green'))
#
# list index out of range
#
#
# list index out of range
#     data = [trace1, trace2, trace3]
#
# list index out of range
#
#
# list index out of range
#     layout = go.Layout(
#
# list index out of range
#         title=titulo,
#
# list index out of range
#         # width=1800,
#
# list index out of range
#         xaxis=dict(
#
# list index out of range
#             title='Tiempo (h)',
#
# list index out of range
#             # showticklabels=True,
#
# list index out of range
#             # domain=[0.03, 0.94]
#
# list index out of range
#         ),
#
# list index out of range
#         yaxis=dict(
#
# list index out of range
#             # title='Variable',
#
# list index out of range
#             showticklabels=True,
#
# list index out of range
#             titlefont=dict(color='blue'),
#
# list index out of range
#             tickfont=dict(color='blue')
#
# list index out of range
#         ),
#
# list index out of range
#         yaxis2=dict(
#
# list index out of range
#             # title='yaxis2 title',
#
# list index out of range
#             showticklabels=True,
#
# list index out of range
#             titlefont=dict(color='orange'),
#
# list index out of range
#             tickfont=dict(color='orange'),
#
# list index out of range
#             anchor='free',
#
# list index out of range
#             overlaying='y',
#
# list index out of range
#             side='left',
#
# list index out of range
#             # position=0.0
#
# list index out of range
#         ),
#
# list index out of range
#         yaxis3=dict(
#
# list index out of range
#             # title='yaxis4 title',
#
# list index out of range
#             showticklabels=True,
#
# list index out of range
#             titlefont=dict(color='green'),
#
# list index out of range
#             tickfont=dict(color='green'),
#
# list index out of range
#             anchor='x',
#
# list index out of range
#             overlaying='y',
#
# list index out of range
#             side='right'
#
# list index out of range
#         )
#
# list index out of range
#     )
#
# list index out of range
#
#
# list index out of range
#     fig = go.Figure(data=data, layout=layout)
#
# list index out of range
#     if toh==1:
#
# list index out of range
#         plotly.offline.plot(fig, filename="D:\Documentos\PIMEDICA\Calibracion_sensores\sensores\Regresion\\resultados_ajustes\\Humedad_Graf_" + nombre + "_" + fecha + '.html')
#
# list index out of range
#     elif toh==2:
#
# list index out of range
#         plotly.offline.plot(fig, filename="D:\Documentos\PIMEDICA\Calibracion_sensores\sensores\Regresion\\resultados_ajustes\\Temperatura_Graf_" + nombre + "_" + fecha + '.html')
#
# list index out of range
#     elif toh == 3:
#
# list index out of range
#         plotly.offline.plot(fig, filename="D:\Documentos\PIMEDICA\Calibracion_sensores\sensores\Regresion\\resultados_ajustes\\Sonda_Graf_" + nombre + "_" + fecha + '.html')
#
# list index out of range
#     elif toh == 4:
#
# list index out of range
#         plotly.offline.plot(fig, filename="D:\Documentos\PIMEDICA\Calibracion_sensores\sensores\Regresion\\resultados_ajustes\\Camara_cruda_Graf_" + nombre + "_" + fecha + '.html')
#
# list index out of range
#     elif toh ==5:
#
# list index out of range
#         titulo = 'Regresion Temp ' + nombregrafica
#
# list index out of range
#
#
# list index out of range
#         trace1 = go.Scatter(x=x1, y=y1, name=n1,mode = 'markers', marker=dict(color='blue'))
#
# list index out of range
#         data = [trace1, trace2, trace3]
#
# list index out of range
#         layout = go.Layout(
#
# list index out of range
#             title=titulo,
#
# list index out of range
#             # width=1800,
#
# list index out of range
#             xaxis=dict(
#
# list index out of range
#                 title='Temperatura camara',
#
# list index out of range
#                 # showticklabels=True,
#
# list index out of range
#                 # domain=[0.03, 0.94]
#
# list index out of range
#             ),
#
# list index out of range
#             yaxis=dict(
#
# list index out of range
#                 title='Temperatura sensor',
#
# list index out of range
#                 showticklabels=True,
#
# list index out of range
#                 titlefont=dict(color='blue'),
#
# list index out of range
#                 tickfont=dict(color='blue')
#
# list index out of range
#             ),
#
# list index out of range
#             yaxis2=dict(
#
# list index out of range
#                 # title='yaxis2 title',
#
# list index out of range
#                 showticklabels=True,
#
# list index out of range
#                 titlefont=dict(color='orange'),
#
# list index out of range
#                 tickfont=dict(color='orange'),
#
# list index out of range
#                 anchor='free',
#
# list index out of range
#                 overlaying='y',
#
# list index out of range
#                 side='left',
#
# list index out of range
#                 # position=0.0
#
# list index out of range
#             ),
#
# list index out of range
#
#
# list index out of range
#
#
# list index out of range
# •	Guarapo de bienvenida con panela orgánica de nuestro trapiche tradicional.
#
# list index out of range
# •	 Alojamiento en cabaña en guadua con balcones y   hamacas
#
# list index out of range
# •	2 deliciosas y saludables comidas  (desayuno y almuerzo).
#
# list index out of range
# •	Zonas húmedas del Eco hotel, piscina natural, baño turco con una hermosa     vista a la fauna y la flora, Jacuzzis de agua caliente y agua fría en medio de la naturaleza.
#
# list index out of range
# •	Actividad de empoderamiento y escalada breve en cascada de agua cristalina e hidroterapia dirigida.
#
# list index out of range
# •	Auto masaje de guayaba y áloe vera.
#
# list index out of range
# •	Fogata en la noche.
#
# list index out of range
#
#
# list index out of range
# VALOR EN CABAÑA
#
# list index out of range
#  Valor semana: $179.000 por persona por noche
#
# list index out of range
# Valor fin de semana: $219.000 por persona por noche.
#
# list index out of range
# Valor temporada alta y puente festivo: $241.000 por persona por noche.
#
# list index out of range
# Valor seguro hotelero: $5.000 por persona por noche.
#
# list index out of range
#
#
# list index out of range
# Eco + 	Caminata guiada por camino ancestral de 1200 años,  construido por los indígenas hasta trapiche de panela y visita a casas campesinas amobladas en guadua, Concierto de silencio en nacimiento de agua.
#
# list index out of range
#
#
# list index out of range
# VALOR EN CABAÑA
#
# list index out of range
# Valor  semana: $199.000 por persona por noche.
#
# list index out of range
# Valor fin de semana: $237.000 por persona por noche.
#
# list index out of range
# Valor puente festivo: $261.000 por persona por noche.
#
# list index out of range
# Valor seguro hotelero: $5.000 por persona por noche.
#
# list index out of range
# Jajajajajajajajajajajajaja
#
# list index out of range
# Isimo
#
# list index out of range
# Arenas
#
# list index out of range
# Ba
#
# list index out of range
# Felipe
#
# list index out of range
# Vallejo
#
# list index out of range
# https://open.spotify.com/episode/4jZ28H5txKFFKpYwuqIBDz?si=8K85L2SGRhWQFf62B5Iy2g
#
# list index out of range
# En bancolombia
#
# list index out of range
#
#
# list index out of range
# Estamos felices de que quieras trabajar con nosotros en la construcción de sueños de millones de colombianos 👩🏽‍🎓👨🏽‍🎓🏡✈🏖👪👨‍👧‍👧
#
# list index out of range
#
#
# list index out of range
# Para continuar con el proceso de selección para el cargo, te invitamos a una entrevista (presencial) el día 04 febrero, a las 2:00pm 📆👩🏼‍💻
#
# list index out of range
# Al correo te llego un caso el cual debes traerlo resuelto para este día
#
# list index out of range
# Dirección: Calle 49 # 63 – 100 Torre Protección  (física) 📍
#
# list index out of range
# ¡Feliz día! ☀
#
# list index out of range

# %%
display(df.head()) 
display(df.name.unique())
df.iloc[0,:].message
# Out:
#                  date              name  \
# 0 2018-12-31 09:41:00  David Betancur S
# 1 2018-12-31 09:41:00  David Betancur S
# 2 2018-12-31 10:26:00  Tomas Echavarría
# 3 2018-12-31 10:29:00  Tomas Echavarría
# 4 2018-12-31 10:29:00  Tomas Echavarría
#
#                                      message
# 0                                      Men\n
# 1   Sabes la direccion de ferfer en paris?\n
# 2                     <Multimedia omitido>\n
# 3                     <Multimedia omitido>\n
# 4                     <Multimedia omitido>\n
# array(['David Betancur S', 'Tomas Echavarría'], dtype=object)
# ' Men\n'

# %%
plt.figure(figsize=(15,5))
horas = plot_hours(df)

# %%
wc = general_cloud(df)

# %%
plot_count(df)

# %%
plot_word(df, "si", 500)
