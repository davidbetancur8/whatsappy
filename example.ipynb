# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
from whatsappy.wppy import parse_file, plot_word, plot_count, general_cloud
df = parse_file(tipo=2, text_file='chats/manu.txt')
display(df.head()) 
display(df.name.unique())
df.iloc[0,:].message
# Out:
#                  date              name         message
# 0 2019-12-17 10:38:00   Manuela Montoya           Hello
# 1 2019-12-17 10:40:00  David Betancur S          Hola!!
# 2 2019-12-17 10:40:00  David Betancur S  Malas noticias
# 3 2019-12-17 10:40:00  David Betancur S    Me dió gripa
# 4 2019-12-17 10:40:00   Manuela Montoya             Ash
# array(['Manuela Montoya', 'David Betancur S'], dtype=object)
# 'Hello'

# %%
general_cloud(df)

# %%
plot_count(df)

# %%
plot_word(df, "si", 500)
